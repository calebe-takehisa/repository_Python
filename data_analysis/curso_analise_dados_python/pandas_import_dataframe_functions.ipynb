# %%
import pandas as pd
import numpy as np

# %%
tabela_campeonato = pd.read_csv('tabela_campeonato.csv')

# %%
tabela_campeonato
# Out:
#      Horário      Dia        Data        Clube 1      Clube 2       Vencedor  \
# 0      16h00   Sábado  2000-07-29     Fluminense        Bahia     Fluminense
# 1      16h00   Sábado  2000-07-29          Vasco        Sport          Sport
# 2      16h00   Sábado  2000-07-29        Vitória    Palmeiras        Vitória
# 3      17h00  Domingo  2000-07-30    Botafogo-RJ  Atlético-MG              -
# 4      18h30  Domingo  2000-07-30      Juventude     Flamengo              -
# ...      ...      ...         ...            ...          ...            ...
# 7934   17:00  Domingo  2019-12-08          Goiás       Grêmio          Goiás
# 7935   17:00  Domingo  2019-12-08  Internacional  Atlético-MG  Internacional
# 7936   17:00  Domingo  2019-12-08       Cruzeiro    Palmeiras      Palmeiras
# 7937   17:00  Domingo  2019-12-08         Santos     Flamengo         Santos
# 7938   17:00  Domingo  2019-12-08            CSA    São Paulo      São Paulo
#
# ...

# %%
#comandos para entender os dados

# %%
tabela_campeonato.head(6)
# Out:
#   Horário      Dia        Data      Clube 1      Clube 2    Vencedor  \
# 0   16h00   Sábado  2000-07-29   Fluminense        Bahia  Fluminense
# 1   16h00   Sábado  2000-07-29        Vasco        Sport       Sport
# 2   16h00   Sábado  2000-07-29      Vitória    Palmeiras     Vitória
# 3   17h00  Domingo  2000-07-30  Botafogo-RJ  Atlético-MG           -
# 4   18h30  Domingo  2000-07-30    Juventude     Flamengo           -
# 5   16h00  Domingo  2000-07-30      Guarani   Santa Cruz           -
#
#       Rodada           Arena  Clube 1 Gols  Clube 2 Gols Clube 1 Estado  \
# 0  1ª Rodada        Maracanã             2             0             RJ
# 1  1ª Rodada    São Januário             0             2             RJ
# 2  1ª Rodada        Barradão             4             1             ES
# 3  1ª Rodada    Caio Martins             0             0             RJ
# 4  1ª Rodada  Alfredo Jaconi             1             1             RS
# ...

# %%
tabela_campeonato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7939 entries, 0 to 7938
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Horário                7582 non-null   object
#  1   Dia                    7939 non-null   object
#  2   Data                   7939 non-null   object
#  3   Clube 1                7939 non-null   object
#  4   Clube 2                7939 non-null   object
#  5   Vencedor               7939 non-null   object
#  6   Rodada                 7939 non-null   object
#  7   Arena                  7939 non-null   object
#  8   Clube 1 Gols           7939 non-null   int64
#  9   Clube 2 Gols           7939 non-null   int64
#  10  Clube 1 Estado         7939 non-null   object
#  11  Clube 2 Estado         7939 non-null   object
#  12  Estado Clube Vencedor  7939 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 806.4+ KB

# %%
#Qual foi a média de gols do time clube 1?

# %%
tabela_campeonato['Clube 1 Gols'].mean()
# Out:
# 1.5968006046101524

# %%
#Qual foi a média de gols do time clube 2?

# %%
tabela_campeonato['Clube 2 Gols'].mean()
# Out:
# 1.0525255069908048

# %%
#Total de gols na partida?

# %%
tabela_campeonato['Total de Gols'] = tabela_campeonato['Clube 1 Gols'] + tabela_campeonato['Clube 2 Gols']

# %%
tabela_campeonato.head()
# Out:
#   Horário      Dia        Data      Clube 1      Clube 2    Vencedor  \
# 0   16h00   Sábado  2000-07-29   Fluminense        Bahia  Fluminense
# 1   16h00   Sábado  2000-07-29        Vasco        Sport       Sport
# 2   16h00   Sábado  2000-07-29      Vitória    Palmeiras     Vitória
# 3   17h00  Domingo  2000-07-30  Botafogo-RJ  Atlético-MG           -
# 4   18h30  Domingo  2000-07-30    Juventude     Flamengo           -
#
#       Rodada           Arena  Clube 1 Gols  Clube 2 Gols Clube 1 Estado  \
# 0  1ª Rodada        Maracanã             2             0             RJ
# 1  1ª Rodada    São Januário             0             2             RJ
# 2  1ª Rodada        Barradão             4             1             ES
# 3  1ª Rodada    Caio Martins             0             0             RJ
# 4  1ª Rodada  Alfredo Jaconi             1             1             RS
#
#   Clube 2 Estado Estado Clube Vencedor  Total de Gols
# 0             BA                    RJ              2
# ...

# %%
#Media de gols por partida?

# %%
tabela_campeonato['Total de Gols'].mean()
# Out:
# 2.649326111600957

# %%
#Qual foi o time com mais vitorias?

# %%
tabela_campeonato['Vencedor'].value_counts()
# Out:
# -                  2040
# São Paulo           348
# Cruzeiro            322
# Santos              319
# Grêmio              308
# Internacional       302
# Flamengo            298
# Corinthians         293
# Athlético-PR        291
# Fluminense          288
# Atlético-MG         282
# Palmeiras           279
# Vasco               216
# Goiás               214
# Botafogo-RJ         205
# Coritiba            187
# Vitória             152
# Figueirense         151
# Ponte Preta         149
# Sport               127
# Bahia               123
# Paraná              104
# São Caetano         103
# Juventude            96
# Chapecoense          69
# Guarani              63
# Avaí                 57
# Portuguesa           57
# Náutico              54
# Fortaleza            51
# Paysandu             50
# Criciúma             50
# Ceará                40
# Atlético-GO          39
# América-MG           38
# Botafogo-rj          26
# Santa Cruz           25
# Gama                 21
# ...

# %%
# A coluna Vencedor apresentou nomes maiusculos e minusculos e o Python considera como 2 elementos diferentes, realize a correção.

# %%
tabela_campeonato['Vencedor'] = tabela_campeonato['Vencedor'].str.upper()

# %%
tabela_campeonato['Vencedor'].value_counts()
# Out:
# -                  2040
# SÃO PAULO           348
# CRUZEIRO            326
# SANTOS              325
# GRÊMIO              308
# INTERNACIONAL       303
# FLAMENGO            299
# CORINTHIANS         296
# FLUMINENSE          292
# ATHLÉTICO-PR        291
# ATLÉTICO-MG         282
# PALMEIRAS           280
# BOTAFOGO-RJ         231
# VASCO               220
# GOIÁS               214
# CORITIBA            187
# VITÓRIA             152
# FIGUEIRENSE         151
# PONTE PRETA         150
# SPORT               129
# BAHIA               123
# PARANÁ              104
# SÃO CAETANO         103
# JUVENTUDE            96
# CHAPECOENSE          69
# GUARANI              63
# PORTUGUESA           58
# AVAÍ                 57
# NÁUTICO              54
# FORTALEZA            51
# CRICIÚMA             50
# PAYSANDU             50
# CEARÁ                40
# ATLÉTICO-GO          39
# AMÉRICA-MG           38
# SANTA CRUZ           25
# GAMA                 21
# BARUERI              12
# ...

# %%
#Qual o estado com maior número de vitórias?

# %%
tabela_campeonato['Estado Clube Vencedor'].value_counts()
# Out:
# Empate    2040
# SP        1659
# RJ        1042
# RS         707
# MG         655
# PR         582
# SC         334
# GO         253
# PE         208
# ES         152
# BA         123
# CE          91
# PA          50
# DF          31
# AL           8
# RN           4
# Name: Estado Clube Vencedor, dtype: int64

# %%
#Ordene a tabela pelo maior número de gols do clube 1.

# %%
tabela_campeonato.sort_values(by='Clube 1 Gols', ascending = False)
# Out:
#      Horário           Dia        Data        Clube 1       Clube 2  \
# 693    16h00       Domingo  2001-11-25          Vasco     São Paulo
# 1122   16h00       Domingo  2003-04-27          Goiás     Juventude
# 1992   20h30   Terça-feira  2004-09-28      São Paulo      Paysandu
# 2309   21h45  Quarta-feira  2005-07-27   Athlético-PR         Vasco
# 357    14h30       Domingo  2001-08-05          Vasco       Guarani
# ...      ...           ...         ...            ...           ...
# 6365   18h00       Domingo  2015-11-01          Vasco    Fluminense
# 6364   17h00       Domingo  2015-11-01    Atlético-MG   Corinthians
# 6363   17h00       Domingo  2015-11-01    Chapecoense  Athlético-PR
# 4253   16h00       Domingo  2010-08-01  Internacional        Grêmio
# 2956   20h30  Quinta-feira  2006-11-09     Fluminense   Ponte Preta
#
#           Vencedor      Rodada             Arena  Clube 1 Gols  Clube 2 Gols  \
# ...

# %%
#Descubra quais são os valores unicos da coluna Clube 1.

# %%
tabela_campeonato['Clube 1'] = tabela_campeonato['Clube 1'].str.upper()

# %%
tabela_campeonato['Clube 2'] = tabela_campeonato['Clube 2'].str.upper()

# %%
tabela_campeonato['Clube 1'].unique()
# Out:
# array(['FLUMINENSE', 'VASCO', 'VITÓRIA', 'BOTAFOGO-RJ', 'JUVENTUDE',
#        'GUARANI', 'CRUZEIRO', 'AMÉRICA-MG', 'GOIÁS', 'CORITIBA', 'BAHIA',
#        'FLAMENGO', 'GAMA', 'INTERNACIONAL', 'PONTE PRETA', 'SANTOS',
#        'PALMEIRAS', 'ATHLÉTICO-PR', 'CORINTHIANS', 'ATLÉTICO-MG',
#        'PORTUGUESA', 'GRÊMIO', 'SÃO PAULO', 'SANTA CRUZ', 'SPORT',
#        'PARANÁ', 'REMO', 'SÃO CAETANO', 'MALUTROM', 'BOTAFOGO-SP',
#        'FIGUEIRENSE', 'PAYSANDU', 'FORTALEZA', 'CRICIÚMA', 'BRASILIENSE',
#        'AMÉRICA-RN', 'NÁUTICO', 'IPATINGA', 'AVAÍ', 'SANTO ANDRÉ',
#        'BARUERI', 'ATLÉTICO-GO', 'CEARÁ', 'GRÊMIO PRUDENTE',
#        'CHAPECOENSE', 'JOINVILLE', 'CSA'], dtype=object)

# %%
#Descubra quais é o total valores unicos da coluna Clube 1.

# %%
tabela_campeonato['Clube 1'].nunique()
# Out:
# 47

# %%
#Qual foi a maior goleada de todos os tempos?

# %%
tabela_campeonato[tabela_campeonato['Clube 1 Gols'] == tabela_campeonato['Clube 1 Gols'].max()]
# Out:
#      Horário           Dia        Data       Clube 1    Clube 2      Vencedor  \
# 357    14h30       Domingo  2001-08-05         VASCO    GUARANI         VASCO
# 693    16h00       Domingo  2001-11-25         VASCO  SÃO PAULO         VASCO
# 1122   16h00       Domingo  2003-04-27         GOIÁS  JUVENTUDE         GOIÁS
# 1671   16h00       Domingo  2004-05-16      CRICIÚMA      GOIÁS      CRICIÚMA
# 1992   20h30   Terça-feira  2004-09-28     SÃO PAULO   PAYSANDU     SÃO PAULO
# 2055   20h30  Quarta-feira  2004-10-27    FLUMINENSE  JUVENTUDE    FLUMINENSE
# 2309   21h45  Quarta-feira  2005-07-27  ATHLÉTICO-PR      VASCO  ATHLÉTICO-PR
# 2557   16h00       Domingo  2005-11-06   CORINTHIANS     SANTOS   CORINTHIANS
#
#           Rodada                Arena  Clube 1 Gols  Clube 2 Gols  \
# 357    2ª Rodada         São Januário             7             1
# 693   26ª Rodada         São Januário             7             1
# 1122   6ª Rodada        Serra Dourada             7             0
# ...

# %%
# Qual o time fez mais gols no campeonato brasileiro?

# %%
by_clube1 = tabela_campeonato.groupby('Clube 1')

# %%
by_clube1['Clube 1 Gols'].sum().sort_values(ascending= False)
# Out:
# Clube 1
# SANTOS             701
# CRUZEIRO           668
# SÃO PAULO          663
# ATLÉTICO-MG        620
# ATHLÉTICO-PR       618
# GRÊMIO             612
# FLAMENGO           602
# FLUMINENSE         576
# PALMEIRAS          564
# INTERNACIONAL      563
# CORINTHIANS        552
# BOTAFOGO-RJ        517
# VASCO              514
# GOIÁS              502
# CORITIBA           404
# VITÓRIA            394
# PONTE PRETA        346
# FIGUEIRENSE        325
# SPORT              302
# BAHIA              275
# PARANÁ             231
# JUVENTUDE          211
# SÃO CAETANO        185
# PAYSANDU           159
# PORTUGUESA         149
# AVAÍ               147
# CHAPECOENSE        136
# FORTALEZA          134
# GUARANI            131
# NÁUTICO            131
# CRICIÚMA           121
# AMÉRICA-MG         103
# ATLÉTICO-GO         95
# CEARÁ               94
# SANTA CRUZ          78
# GAMA                53
# BARUERI             35
# SANTO ANDRÉ         29
# IPATINGA            28
# ...
